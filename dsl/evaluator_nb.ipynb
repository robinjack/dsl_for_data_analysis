# %%
from dsl.evaluator import *
from semantic_model.data import Data
from textx import metamodel_from_file, metamodel_from_str

# %%
meta = metamodel_from_file('analysis_flow.tx')

# %%
model = meta.model_from_file('../examples/simple_model.analysis')
d = Data('../examples/iris.csv')

d.set_target('sepal_length')
# Out:
# ---------------------------------------------------------------------------
# NoMatch                                   Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/textx/model.py in _parse(self)
#     220             try:
# --> 221                 return self.parser_model.parse(self)
#     222             except NoMatch as e:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     480                     append(sep_result)
# --> 481                 result = p(parser)
#     482                 if not result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     417         if not match:
# --> 418             parser._nm_raise(self, c_pos, parser)
#     419
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     417         if not match:
# --> 418             parser._nm_raise(self, c_pos, parser)
#     419
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     417         if not match:
# --> 418             parser._nm_raise(self, c_pos, parser)
#     419
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     417         if not match:
# --> 418             parser._nm_raise(self, c_pos, parser)
#     419
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     850                 parser.dprint("-- NoMatch at {}".format(c_pos))
# --> 851             parser._nm_raise(self, c_pos, parser)
#     852
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     417         if not match:
# --> 418             parser._nm_raise(self, c_pos, parser)
#     419
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     417         if not match:
# --> 418             parser._nm_raise(self, c_pos, parser)
#     419
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     403                 try:
# --> 404                     result = e.parse(parser)
#     405                     if result is not None:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# NoMatch: Expected 'LOAD' at position ../examples/simple_model.analysis:(6, 1) => '  = data2 *x = 1 log('.
#
# During handling of the above exception, another exception occurred:
#
# TextXSyntaxError                          Traceback (most recent call last)
# <ipython-input-25-2862b67840d8> in <module>
# ----> 1 model = meta.model_from_file('../examples/simple_model.analysis')
#       2 d = Data('../examples/iris.csv')
#       3
#       4 d.set_target('sepal_length')
#       5
#
# /usr/local/lib/python3.7/site-packages/textx/metamodel.py in model_from_file(self, file_name, encoding, debug)
#     572
#     573     def model_from_file(self, file_name, encoding='utf-8', debug=None):
# --> 574         return self.internal_model_from_file(file_name, encoding, debug)
#     575
#     576     def internal_model_from_file(
#
# /usr/local/lib/python3.7/site-packages/textx/metamodel.py in internal_model_from_file(self, file_name, encoding, debug, pre_ref_resolution_callback, is_main_model, model_str)
#     614                 model_str, file_name, debug=debug, encoding=encoding,
#     615                 pre_ref_resolution_callback=callback,
# --> 616                 is_main_model=is_main_model)
#     617
#     618         for p in self._model_processors:
#
# /usr/local/lib/python3.7/site-packages/textx/model.py in get_model_from_str(self, model_str, file_name, debug, pre_ref_resolution_callback, is_main_model, encoding)
#     260                     self.dprint("*** PARSING MODEL ***")
#     261
# --> 262                 self.parse(model_str, file_name=file_name)
#     263                 # Transform parse tree to model. Skip root node which
#     264                 # represents the whole file ending in EOF.
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, _input, file_name)
#    1491         self.cache_misses = 0
#    1492         try:
# -> 1493             self.parse_tree = self._parse()
#    1494         except NoMatch as e:
#    1495             # Remove Not marker
#
# /usr/local/lib/python3.7/site-packages/textx/model.py in _parse(self)
#     225                                        line=line,
#     226                                        col=col,
# --> 227                                        expected_rules=e.rules)
#     228
#     229         def get_model_from_file(self, file_name, encoding, debug,
#
# TextXSyntaxError: None:6:1: error: Expected 'LOAD' at position ../examples/simple_model.analysis:(6, 1) => '  = data2 *x = 1 log('.

# %%
def explore_model(input_string):
    test_model = meta.model_from_str(input_string)
# Out:
# ---------------------------------------------------------------------------
# NoMatch                                   Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/textx/lang.py in language_from_str(language_def, metamodel)
#     927     try:
# --> 928         parse_tree = parser.parse(language_def)
#     929     except NoMatch as e:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, _input, file_name)
#    1492         try:
# -> 1493             self.parse_tree = self._parse()
#    1494         except NoMatch as e:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self)
#    1746     def _parse(self):
# -> 1747         return self.parser_model.parse(self)
#    1748
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     938                 parser.dprint("!! EOF not matched.")
# --> 939             parser._nm_raise(self, c_pos, parser)
#     940
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     480                     append(sep_result)
# --> 481                 result = p(parser)
#     482                 if not result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     445         try:
# --> 446             result = [self.nodes[0].parse(parser)]
#     447         except NoMatch:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     285         try:
# --> 286             result = self._parse(parser)
#     287             if self.suppress or (type(result) is list and
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     364             for e in self.nodes:
# --> 365                 result = e.parse(parser)
#     366                 if result:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in parse(self, parser)
#     785
# --> 786         result = self._parse(parser)
#     787         if not self.suppress:
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _parse(self, parser)
#     892                             parser.context(len(self.to_match))))
# --> 893             parser._nm_raise(self, c_pos, parser)
#     894
#
# /usr/local/lib/python3.7/site-packages/arpeggio/__init__.py in _nm_raise(self, *args)
#    1694
# -> 1695         raise self.nm
#    1696
#
# NoMatch: Expected '[' or ':' at position (1, 3) => 'x *= 1 \n end'.
#
# During handling of the above exception, another exception occurred:
#
# TextXSyntaxError                          Traceback (most recent call last)
# <ipython-input-22-5f8e2771c203> in <module>
#       1 while True:
#       2     input_string = input()
# ----> 3     test_model = metamodel_from_str(input_string)
#       4
#
# /usr/local/lib/python3.7/site-packages/textx/metamodel.py in metamodel_from_str(lang_desc, metamodel, **kwargs)
#      39         metamodel = TextXMetaModel(**kwargs)
#      40
# ---> 41     language_from_str(lang_desc, metamodel)
#      42
#      43     return metamodel
#
# /usr/local/lib/python3.7/site-packages/textx/lang.py in language_from_str(language_def, metamodel)
#     929     except NoMatch as e:
#     930         line, col = parser.pos_to_linecol(e.position)
# --> 931         raise TextXSyntaxError(text(e), line, col)
#     932
#     933     # Construct new parser and meta-model based on the given language
#
# TextXSyntaxError: None:1:3: error: Expected '[' or ':' at position (1, 3) => 'x *= 1 \n end'.

# %%
model
# Out:
# <textx:analysis_flow.Program instance at 0x11eb57210>
